# %%
from matplotlib import pyplot as plt
import numpy as np
import csv

# %%
frame_emotions = []
FER_Andy = []

with open('emotion_andy.csv') as reader:
#     reader = csv.DictReader(csvDataFile)
    for row in reader:
        row.strip('\n')
        print(row)
        frame_emotions.append(row)
#         FER_Andy.append(float(row['Andy']))
# Out:
# andyface_resize_frame24636.jpg:fear
#
# andyface_resize_frame07777.jpg:surprise
#
# andyface_resize_frame31212.jpg:disgust
#
# andyface_resize_frame24278.jpg:fear
#
# andyface_resize_frame12284.jpg:fear
#
# andyface_resize_frame15522.jpg:fear
#
# andyface_resize_frame21213.jpg:fear
#
# andyface_resize_frame30018.jpg:anger
#
# andyface_resize_frame30647.jpg:disgust
#
# andyface_resize_frame10344.jpg:happy
#
# andyface_resize_frame27557.jpg:happy
#
# andyface_resize_frame24415.jpg:fear
#
# andyface_resize_frame30328.jpg:anger
#
# andyface_resize_frame24245.jpg:fear
#
# andyface_resize_frame30153.jpg:anger
#
# andyface_resize_frame16385.jpg:fear
#
# andyface_resize_frame11458.jpg:fear
#
# andyface_resize_frame22715.jpg:fear
#
# andyface_resize_frame30014.jpg:anger
#
# andyface_resize_frame34745.jpg:anger
#
# andyface_resize_frame00366.jpg:anger
#
# andyface_resize_frame00601.jpg:anger
#
# andyface_resize_frame20820.jpg:anger
#
# andyface_resize_frame27403.jpg:fear
#
# ...

# %%
frame_emotions = []
FER_Andy = []

with open('emotion_tommy.csv') as reader:
#     reader = csv.DictReader(csvDataFile)
    for row in reader:
        row.strip('\n')
        print(row)
        frame_emotions.append(row)
#         FER_Andy.append(float(row['Andy']))
# Out:
# face_tommy_frame25519.jpg:disgust
#
# face_tommy_frame26267.jpg:fear
#
# face_tommy_frame26206.jpg:fear
#
# face_tommy_frame25626.jpg:fear
#
# face_tommy_frame25591.jpg:fear
#
# face_tommy_frame25673.jpg:anger
#
# face_tommy_frame26295.jpg:surprise
#
# face_tommy_frame25550.jpg:anger
#
# face_tommy_frame26214.jpg:anger
#
# face_tommy_frame26717.jpg:fear
#
# face_tommy_frame25549.jpg:anger
#
# face_tommy_frame25535.jpg:disgust
#
# face_tommy_frame26211.jpg:fear
#
# face_tommy_frame28155.jpg:fear
#
# face_tommy_frame26957.jpg:fear
#
# face_tommy_frame27018.jpg:surprise
#
# face_tommy_frame26289.jpg:surprise
#
# face_tommy_frame26927.jpg:fear
#
# face_tommy_frame26294.jpg:fear
#
# face_tommy_frame25570.jpg:fear
#
# face_tommy_frame28148.jpg:anger
#
# face_tommy_frame26247.jpg:fear
#
# face_tommy_frame25530.jpg:anger
#
# face_tommy_frame26909.jpg:fear
#
# face_tommy_frame25527.jpg:anger
#
# face_tommy_frame25560.jpg:anger
#
# face_tommy_frame25317.jpg:anger
#
# ...

# %%
frame_emotions.sort()
print(frame_emotions)
# Out:
# ['andyface_resize_frame00245.jpg:anger\n', 'andyface_resize_frame00247.jpg:fear\n', 'andyface_resize_frame00252.jpg:anger\n', 'andyface_resize_frame00254.jpg:fear\n', 'andyface_resize_frame00271.jpg:fear\n', 'andyface_resize_frame00293.jpg:anger\n', 'andyface_resize_frame00294.jpg:disgust\n', 'andyface_resize_frame00295.jpg:anger\n', 'andyface_resize_frame00296.jpg:disgust\n', 'andyface_resize_frame00297.jpg:disgust\n', 'andyface_resize_frame00298.jpg:anger\n', 'andyface_resize_frame00299.jpg:anger\n', 'andyface_resize_frame00300.jpg:anger\n', 'andyface_resize_frame00301.jpg:anger\n', 'andyface_resize_frame00302.jpg:anger\n', 'andyface_resize_frame00303.jpg:anger\n', 'andyface_resize_frame00304.jpg:disgust\n', 'andyface_resize_frame00305.jpg:disgust\n', 'andyface_resize_frame00306.jpg:anger\n', 'andyface_resize_frame00307.jpg:anger\n', 'andyface_resize_frame00308.jpg:disgust\n', 'andyface_resize_frame00309.jpg:anger\n', 'andyface_resize_frame00310.jpg:anger\n', 'andyface_resize_frame
# ...

# %%
import re

emotion = []
p = re.compile(':[a-z]+')

for i in frame_emotions:
    match = p.findall(i)
    emotion.append(match)
for emo in emotion:
    print(emo)
#     emo.strip(':')
    
print(emotion)
# Out:
# [':anger']
# [':fear']
# [':anger']
# [':fear']
# [':fear']
# [':anger']
# [':disgust']
# [':anger']
# [':disgust']
# [':disgust']
# [':anger']
# [':anger']
# [':anger']
# [':anger']
# [':anger']
# [':anger']
# [':disgust']
# [':disgust']
# [':anger']
# [':anger']
# [':disgust']
# [':anger']
# [':anger']
# [':anger']
# [':disgust']
# [':disgust']
# [':anger']
# [':anger']
# [':anger']
# [':anger']
# [':disgust']
# [':anger']
# [':anger']
# [':disgust']
# [':anger']
# [':disgust']
# [':anger']
# [':anger']
# [':anger']
# [':anger']
# [':anger']
# [':fear']
# [':anger']
# [':anger']
# [':anger']
# [':anger']
# [':anger']
# [':anger']
# [':anger']
# [':anger']
# [':anger']
# [':anger']
# [':disgust']
# [':disgust']
# [':disgust']
# [':disgust']
# [':disgust']
# [':disgust']
# [':disgust']
# [':anger']
# [':anger']
# [':surprise']
# [':anger']
# [':disgust']
# [':anger']
# [':disgust']
# [':anger']
# [':anger']
# [':disgust']
# [':disgust']
# [':disgust']
# [':anger']
# [':disgust']
# ...

# %%
frame e
